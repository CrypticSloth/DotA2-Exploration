# %%
from plotly import __version__
from plotly.offline import init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import numpy as np
import json
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
plotly.__version__
# Out:
# '2.7.0'

# %%
with open('../../versions_test/7.17/3944571593.json', 'r') as json_file:  
    data = json.load(json_file)

# %%
# Get player name
data["players"][0]["personaname"]

# Get the players observer ward log
data['players'][0]['obs_log']
data['players'][0]['sen_log']
# Out:
# [{'time': 142,
#   'type': 'sen_log',
#   'key': '[166, 100]',
#   'slot': 0,
#   'x': 166,
#   'y': 100,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 12862719,
#   'player_slot': 0},
#  {'time': 548,
#   'type': 'sen_log',
#   'key': '[168, 96]',
#   'slot': 0,
#   'x': 168,
#   'y': 96,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 6129066,
#   'player_slot': 0},
#  {'time': 794,
#   'type': 'sen_log',
#   'key': '[118, 130]',
#   'slot': 0,
#   'x': 118,
#   'y': 130,
#   'z': 128,
#   'entityleft': False,
#   'ehandle': 7717547,
#   'player_slot': 0},
#  {'time': 895,
#   'type': 'sen_log',
#   'key': '[162, 120]',
#   'slot': 0,
#   'x': 162,
#   'y': 120,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 10880178,
#   'player_slot': 0},
#  {'time': 1136,
#   'type': 'sen_log',
#   'key': '[104, 156]',
#   'slot': 0,
#   'x': 104,
#   'y': 156,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 9553793,
#   'player_slot': 0},
#  {'time': 1473,
#   'type': 'sen_log',
#   'key': '[150, 166]',
#   'slot': 0,
#   'x': 150,
#   'y': 166,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 3065625,
#   'player_slot': 0},
#  {'time': 1537,
#   'type': 'sen_log',
#   'key': '[124, 140]',
#   'slot': 0,
#   'x': 124,
#   'y': 140,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 5407432,
#   'player_slot': 0},
#  {'time': 1611,
#   'type': 'sen_log',
#   'key': '[114, 140]',
#   'slot': 0,
#   'x': 114,
#   'y': 140,
#   'z': 128,
#   'entityleft': False,
#   'ehandle': 13453304,
#   'player_slot': 0},
#  {'time': 1619,
#   'type': 'sen_log',
#   'key': '[122, 138]',
#   'slot': 0,
#   'x': 122,
#   'y': 138,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 8291861,
#   'player_slot': 0},
#  {'time': 1697,
#   'type': 'sen_log',
#   'key': '[156, 138]',
#   'slot': 0,
#   'x': 156,
#   'y': 138,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 11535646,
#   'player_slot': 0},
#  {'time': 1890,
#   'type': 'sen_log',
#   'key': '[158, 114]',
#   'slot': 0,
#   'x': 158,
#   'y': 114,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 2590642,
#   'player_slot': 0},
#  {'time': 1918,
#   'type': 'sen_log',
#   'key': '[166, 126]',
#   'slot': 0,
#   'x': 166,
#   'y': 126,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 1328577,
#   'player_slot': 0},
#  {'time': 2091,
#   'type': 'sen_log',
#   'key': '[124, 138]',
#   'slot': 0,
#   'x': 124,
#   'y': 138,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 9897662,
#   'player_slot': 0},
#  {'time': 2178,
#   'type': 'sen_log',
#   'key': '[112, 138]',
#   'slot': 0,
#   'x': 112,
#   'y': 138,
#   'z': 128,
#   'entityleft': False,
#   'ehandle': 2245813,
#   'player_slot': 0},
#  {'time': 2357,
#   'type': 'sen_log',
#   'key': '[166, 128]',
#   'slot': 0,
#   'x': 166,
#   'y': 128,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 3606491,
#   'player_slot': 0},
#  {'time': 2401,
#   'type': 'sen_log',
#   'key': '[160, 150]',
#   'slot': 0,
#   'x': 160,
#   'y': 150,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 1214045,
#   'player_slot': 0},
#  {'time': 2617,
#   'type': 'sen_log',
#   'key': '[164, 130]',
#   'slot': 0,
#   'x': 164,
#   'y': 130,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 3342519,
#   'player_slot': 0},
#  {'time': 2752,
#   'type': 'sen_log',
#   'key': '[118, 132]',
#   'slot': 0,
#   'x': 118,
#   'y': 132,
#   'z': 128,
#   'entityleft': False,
#   'ehandle': 11731662,
#   'player_slot': 0},
#  {'time': 2781,
#   'type': 'sen_log',
#   'key': '[102, 154]',
#   'slot': 0,
#   'x': 102,
#   'y': 154,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 738993,
#   'player_slot': 0},
#  {'time': 2925,
#   'type': 'sen_log',
#   'key': '[108, 130]',
#   'slot': 0,
#   'x': 108,
#   'y': 130,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 607928,
#   'player_slot': 0},
#  {'time': 2962,
#   'type': 'sen_log',
#   'key': '[120, 122]',
#   'slot': 0,
#   'x': 120,
#   'y': 122,
#   'z': 130,
#   'entityleft': False,
#   'ehandle': 8324446,
#   'player_slot': 0}]

# %%
x_obs = []
y_obs = []
x_sent = []
y_sent = []

for i in data['eventData']['wardEvents']:
    if i['x'] != 0:
        if i['wardType'] == 0:
            x_obs.append(i['x'])
            y_obs.append(i['y'])
        if i['wardType'] == 1:
            x_sent.append(i['x'])
            y_sent.append(i['y'])

# %%
trace1= go.Scatter(x=x_obs + x_sent,y=y_obs + y_sent,
                   mode='markers', 
                   marker = dict(color = "rgb(241, 244, 66)"))

size = 128
layout= go.Layout(width=750,
                  height=750,
                  xaxis=dict(
                      autorange=False,
                      showgrid=False,
                      zeroline=False,
                      ticks='',
                      showticklabels=False,
                      range=[63,192],
                  ),
                  yaxis=dict(
                      autorange=False,
                      showgrid=False,
                      zeroline=False,
                      ticks='',
                      showticklabels=False,
                      range=[63,192]
                  ),
                  images= [dict(
                  source= "https://raw.githubusercontent.com/SorensenErik/DotA2-Exploration/master/analysis/TeamWardAnalysis/actualWards.png",
                  #source = "file:///C:/GitHub/DotA2-Exploration/analysis/TeamWardAnalysis/actualWards.png",
                  xref= "x",
                  yref= "y",
                  x= 63,
                  y= 192,
                  sizex= size,
                  sizey= size,
                  sizing= "stretch",
                  layer= "below")])

# To view plotly graphs in jupyter notebooks on github make sure you are viewing through nbviwer.
# There is a little circle button at the top right, click that and it will allow you to see the plots
fig=go.Figure(data=[trace1],layout=layout)
iplot(fig)
# Out:
# <div id="1a70f143-fd8b-4a1b-89b4-d27b409d6d18" style="height: 750px; width: 750px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1a70f143-fd8b-4a1b-89b4-d27b409d6d18", [{"type": "scatter", "x": [122, 116, 156, 100, 152, 170, 120, 88, 100, 146, 122, 152, 122, 168, 168, 166, 158, 114, 114, 152, 126, 132, 150, 136, 126, 120, 152, 106, 136, 158, 166, 120, 168, 122, 168, 128, 104, 154, 122, 116, 102, 126, 118, 104, 118, 106, 144, 120, 166, 92, 86, 166, 174, 168, 118, 172, 162, 116, 166, 126, 116, 176, 104, 152, 136, 106, 132, 86, 186, 154, 150, 124, 136, 108, 128, 114, 122, 152, 160, 150, 156, 160, 158, 166, 168, 124, 156, 166, 150, 112, 110, 126, 166, 162, 160, 178, 106, 166, 164, 118, 118, 102, 128, 118, 106, 108, 120, 148, 120, 120, 96, 166], "y": [134, 126, 100, 168, 124, 102, 136, 144, 168, 98, 134, 114, 136, 122, 122, 120, 128, 166, 156, 114, 142, 168, 166, 146, 142, 144, 116, 156, 162, 136, 134, 144, 122, 130, 122, 142, 154, 116, 136, 128, 154, 142, 122, 154, 124, 132, 118, 92, 134, 94, 160, 100, 100, 96, 130, 122, 120, 134, 122, 146, 168, 98, 156, 116, 132, 156, 150, 158, 126, 164, 166, 140, 164, 184, 142, 140, 138, 124, 146, 156, 138, 156, 114, 126, 148, 138, 136, 122, 122, 138, 134, 142, 128, 154, 150, 162, 156, 120, 130, 134, 132, 154, 146, 132, 154, 130, 122, 116, 122, 92, 78, 134], "mode": "markers", "marker": {"color": "rgb(241, 244, 66)"}}], {"width": 750, "height": 750, "xaxis": {"autorange": false, "showgrid": false, "zeroline": false, "ticks": "", "showticklabels": false, "range": [63, 192]}, "yaxis": {"autorange": false, "showgrid": false, "zeroline": false, "ticks": "", "showticklabels": false, "range": [63, 192]}, "images": [{"source": "https://raw.githubusercontent.com/SorensenErik/DotA2-Exploration/master/analysis/TeamWardAnalysis/actualWards.png", "xref": "x", "yref": "y", "x": 63, "y": 192, "sizex": 128, "sizey": 128, "sizing": "stretch", "layer": "below"}]}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
